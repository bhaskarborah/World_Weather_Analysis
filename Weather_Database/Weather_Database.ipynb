# %%
# import dependencies
import pandas as pd
import numpy as np
import timeit
import matplotlib.pyplot as plt
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time module.
import time
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# create a list of latitudes and Longitudes and zip them
lat=np.random.uniform(low=-90.000,high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lat,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)# Starting URL for Weather Map API Call.
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=70871b6d4ef4b088296e3a8e6c1a4e1e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description":city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | vanavara
# Processing Record 4 of Set 1 | bonthe
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | ciudad ojeda
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | pontes e lacerda
# Processing Record 11 of Set 1 | pisco
# Processing Record 12 of Set 1 | sahaspur
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | omaruru
# Processing Record 17 of Set 1 | clyde river
# Processing Record 18 of Set 1 | ballina
# Processing Record 19 of Set 1 | atasu
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | ormara
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | rio grande
# Processing Record 24 of Set 1 | otjimbingwe
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | meadow lake
# Processing Record 27 of Set 1 | krasnyy chikoy
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | bria
# Processing Record 31 of Set 1 | muisne
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | olinda
# Processing Record 36 of Set 1 | bathsheba
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | neuquen
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | rosetta
# Processing Record 46 of Set 1 | fomboni
# Processing Record 47 of Set 1 | atripalda
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | bilibino
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 8 of Set 2 | abu samrah
# Processing Record 9 of Set 2 | mitu
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | pangody
# Processing Record 12 of Set 2 | sciacca
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | litoral del san juan
# City not found. Skipping...
# Processing Record 16 of Set 2 | oranjemund
# Processing Record 17 of Set 2 | kikwit
# Processing Record 18 of Set 2 | macomb
# Processing Record 19 of Set 2 | kalur kot
# Processing Record 20 of Set 2 | fayaoue
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | waipawa
# Processing Record 23 of Set 2 | alice springs
# Processing Record 24 of Set 2 | tilichiki
# Processing Record 25 of Set 2 | dolhasca
# Processing Record 26 of Set 2 | maulvi bazar
# City not found. Skipping...
# Processing Record 27 of Set 2 | sayyan
# Processing Record 28 of Set 2 | yar-sale
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | roald
# Processing Record 31 of Set 2 | samoded
# Processing Record 32 of Set 2 | rantepao
# Processing Record 33 of Set 2 | whitehorse
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | norman wells
# Processing Record 36 of Set 2 | phonhong
# Processing Record 37 of Set 2 | kenai
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | novyy urengoy
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | rikitea
# Processing Record 45 of Set 2 | teya
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | aklavik
# Processing Record 48 of Set 2 | comodoro rivadavia
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | hambantota
# Processing Record 1 of Set 3 | margate
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | shakawe
# Processing Record 4 of Set 3 | vestmannaeyjar
# Processing Record 5 of Set 3 | la plata
# Processing Record 6 of Set 3 | harper
# Processing Record 7 of Set 3 | lucea
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 3 | port lincoln
# Processing Record 11 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 3 | petatlan
# Processing Record 13 of Set 3 | cururupu
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | botou
# Processing Record 16 of Set 3 | dennery
# Processing Record 17 of Set 3 | staritsa
# Processing Record 18 of Set 3 | sangar
# Processing Record 19 of Set 3 | khatanga
# Processing Record 20 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 3 | ishigaki
# Processing Record 22 of Set 3 | qabis
# City not found. Skipping...
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | coquimbo
# Processing Record 25 of Set 3 | sao joao batista
# Processing Record 26 of Set 3 | dodola
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | jiangyou
# Processing Record 29 of Set 3 | ewa beach
# Processing Record 30 of Set 3 | sapanta
# Processing Record 31 of Set 3 | almaznyy
# Processing Record 32 of Set 3 | brigantine
# Processing Record 33 of Set 3 | sabzevar
# Processing Record 34 of Set 3 | vaini
# Processing Record 35 of Set 3 | maragogi
# Processing Record 36 of Set 3 | hadishahr
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | aabybro
# Processing Record 39 of Set 3 | sioux lookout
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | arlit
# Processing Record 42 of Set 3 | padang
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | beyneu
# Processing Record 45 of Set 3 | praia da vitoria
# Processing Record 46 of Set 3 | maneadero
# Processing Record 47 of Set 3 | boralday
# Processing Record 48 of Set 3 | isangel
# Processing Record 49 of Set 3 | east london
# Processing Record 50 of Set 3 | saint-louis
# Processing Record 1 of Set 4 | la rioja
# Processing Record 2 of Set 4 | los llanos de aridane
# Processing Record 3 of Set 4 | aquiraz
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | sola
# Processing Record 6 of Set 4 | codrington
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | pocri
# Processing Record 9 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 4 | vao
# Processing Record 11 of Set 4 | salalah
# Processing Record 12 of Set 4 | male
# Processing Record 13 of Set 4 | suntar
# Processing Record 14 of Set 4 | quatre cocos
# Processing Record 15 of Set 4 | fujin
# Processing Record 16 of Set 4 | port-gentil
# Processing Record 17 of Set 4 | hami
# Processing Record 18 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 4 | atar
# Processing Record 20 of Set 4 | saint anthony
# Processing Record 21 of Set 4 | fort smith
# Processing Record 22 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | kupang
# Processing Record 25 of Set 4 | lima
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | ha
# City not found. Skipping...
# Processing Record 28 of Set 4 | knysna
# Processing Record 29 of Set 4 | paamiut
# Processing Record 30 of Set 4 | tevaitoa
# Processing Record 31 of Set 4 | korla
# Processing Record 32 of Set 4 | pindi gheb
# Processing Record 33 of Set 4 | zaysan
# Processing Record 34 of Set 4 | rocha
# Processing Record 35 of Set 4 | giyani
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 4 | zhangjiakou
# Processing Record 39 of Set 4 | bay roberts
# Processing Record 40 of Set 4 | mundo nuevo
# Processing Record 41 of Set 4 | kosa
# Processing Record 42 of Set 4 | yulara
# Processing Record 43 of Set 4 | khatassy
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | nizza monferrato
# Processing Record 46 of Set 4 | balykshi
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | taebla
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 4 | mogadishu
# Processing Record 1 of Set 5 | sambava
# Processing Record 2 of Set 5 | berlevag
# Processing Record 3 of Set 5 | rach gia
# Processing Record 4 of Set 5 | anadyr
# Processing Record 5 of Set 5 | massakory
# Processing Record 6 of Set 5 | alyangula
# Processing Record 7 of Set 5 | chkalovskoye
# Processing Record 8 of Set 5 | van
# Processing Record 9 of Set 5 | dawei
# Processing Record 10 of Set 5 | nelson bay
# Processing Record 11 of Set 5 | ahipara
# Processing Record 12 of Set 5 | oyek
# Processing Record 13 of Set 5 | sao jose da coroa grande
# Processing Record 14 of Set 5 | mareeba
# Processing Record 15 of Set 5 | qaanaaq
# Processing Record 16 of Set 5 | vardo
# Processing Record 17 of Set 5 | namatanai
# Processing Record 18 of Set 5 | dargaville
# Processing Record 19 of Set 5 | saskylakh
# Processing Record 20 of Set 5 | abeokuta
# Processing Record 21 of Set 5 | inuvik
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | tefe
# Processing Record 24 of Set 5 | tavares
# Processing Record 25 of Set 5 | notre-dame-du-lac
# Processing Record 26 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 5 | suez
# Processing Record 28 of Set 5 | mount gambier
# Processing Record 29 of Set 5 | hamilton
# Processing Record 30 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 5 | nambutalai
# Processing Record 32 of Set 5 | general roca
# Processing Record 33 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 5 | cidreira
# Processing Record 35 of Set 5 | mazamari
# Processing Record 36 of Set 5 | castellamonte
# Processing Record 37 of Set 5 | olafsvik
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | coihaique
# Processing Record 40 of Set 5 | inhambane
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | nikolskoye
# Processing Record 43 of Set 5 | srednekolymsk
# Processing Record 44 of Set 5 | samarai
# Processing Record 45 of Set 5 | naze
# Processing Record 46 of Set 5 | camacari
# Processing Record 47 of Set 5 | christchurch
# Processing Record 48 of Set 5 | vacaville
# Processing Record 49 of Set 5 | honningsvag
# Processing Record 50 of Set 5 | play cu
# City not found. Skipping...
# Processing Record 1 of Set 6 | normandin
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | ancud
# Processing Record 6 of Set 6 | makakilo city
# Processing Record 7 of Set 6 | marsh harbour
# Processing Record 8 of Set 6 | san quintin
# Processing Record 9 of Set 6 | teseney
# Processing Record 10 of Set 6 | shubarkuduk
# Processing Record 11 of Set 6 | garowe
# Processing Record 12 of Set 6 | maceio
# Processing Record 13 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 6 | pleasanton
# Processing Record 15 of Set 6 | jinchang
# Processing Record 16 of Set 6 | lubao
# Processing Record 17 of Set 6 | diego de almagro
# Processing Record 18 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 6 | sorong
# Processing Record 20 of Set 6 | cap malheureux
# Processing Record 21 of Set 6 | yeniseysk
# Processing Record 22 of Set 6 | itacoatiara
# Processing Record 23 of Set 6 | sovetskiy
# Processing Record 24 of Set 6 | gushikawa
# Processing Record 25 of Set 6 | tarko-sale
# Processing Record 26 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 27 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 30 of Set 6 | chuy
# Processing Record 31 of Set 6 | carnarvon
# Processing Record 32 of Set 6 | doka
# Processing Record 33 of Set 6 | nanortalik
# Processing Record 34 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 6 | hofn
# Processing Record 36 of Set 6 | gazojak
# Processing Record 37 of Set 6 | batemans bay
# Processing Record 38 of Set 6 | hay river
# Processing Record 39 of Set 6 | ulaanbaatar
# Processing Record 40 of Set 6 | medvezhyegorsk
# Processing Record 41 of Set 6 | changping
# Processing Record 42 of Set 6 | stepnyak
# Processing Record 43 of Set 6 | kargasok
# Processing Record 44 of Set 6 | charkhari
# Processing Record 45 of Set 6 | kyaukse
# Processing Record 46 of Set 6 | samana
# Processing Record 47 of Set 6 | bismarck
# Processing Record 48 of Set 6 | atherton
# Processing Record 49 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 6 | sumenep
# Processing Record 1 of Set 7 | fare
# Processing Record 2 of Set 7 | detva
# Processing Record 3 of Set 7 | okakarara
# Processing Record 4 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 7 | matara
# Processing Record 6 of Set 7 | aksarka
# Processing Record 7 of Set 7 | belmonte
# Processing Record 8 of Set 7 | westport
# Processing Record 9 of Set 7 | fortuna
# Processing Record 10 of Set 7 | mapiripan
# Processing Record 11 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 7 | ketchikan
# Processing Record 14 of Set 7 | dikson
# Processing Record 15 of Set 7 | flinders
# Processing Record 16 of Set 7 | clovis
# Processing Record 17 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 7 | patacamaya
# Processing Record 19 of Set 7 | bambous virieux
# Processing Record 20 of Set 7 | shangrao
# Processing Record 21 of Set 7 | motul
# Processing Record 22 of Set 7 | litovko
# Processing Record 23 of Set 7 | predivinsk
# Processing Record 24 of Set 7 | netrakona
# Processing Record 25 of Set 7 | alanya
# Processing Record 26 of Set 7 | kashan
# Processing Record 27 of Set 7 | caravelas
# Processing Record 28 of Set 7 | krasnopavlivka
# Processing Record 29 of Set 7 | dickinson
# Processing Record 30 of Set 7 | labuhan
# Processing Record 31 of Set 7 | nichinan
# Processing Record 32 of Set 7 | port shepstone
# Processing Record 33 of Set 7 | porto novo
# Processing Record 34 of Set 7 | proletarskiy
# Processing Record 35 of Set 7 | frankfurt
# Processing Record 36 of Set 7 | orlik
# Processing Record 37 of Set 7 | cayenne
# Processing Record 38 of Set 7 | akyab
# Processing Record 39 of Set 7 | seoul
# Processing Record 40 of Set 7 | touros
# Processing Record 41 of Set 7 | palmas
# Processing Record 42 of Set 7 | cherskiy
# Processing Record 43 of Set 7 | elko
# Processing Record 44 of Set 7 | itaberaba
# Processing Record 45 of Set 7 | kloulklubed
# Processing Record 46 of Set 7 | dingle
# Processing Record 47 of Set 7 | sayansk
# Processing Record 48 of Set 7 | bubaque
# Processing Record 49 of Set 7 | sibolga
# Processing Record 50 of Set 7 | along
# Processing Record 1 of Set 8 | fenoarivo
# Processing Record 2 of Set 8 | hasaki
# Processing Record 3 of Set 8 | port macquarie
# Processing Record 4 of Set 8 | alofi
# Processing Record 5 of Set 8 | beringovskiy
# Processing Record 6 of Set 8 | bafia
# Processing Record 7 of Set 8 | auki
# Processing Record 8 of Set 8 | marsa matruh
# Processing Record 9 of Set 8 | visnes
# Processing Record 10 of Set 8 | kavieng
# Processing Record 11 of Set 8 | trinidad
# Processing Record 12 of Set 8 | yellandu
# Processing Record 13 of Set 8 | chimbote
# Processing Record 14 of Set 8 | luganville
# Processing Record 15 of Set 8 | ostroh
# Processing Record 16 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 8 | kununurra
# Processing Record 18 of Set 8 | praia
# Processing Record 19 of Set 8 | valparaiso
# Processing Record 20 of Set 8 | isperih
# Processing Record 21 of Set 8 | dalbandin
# Processing Record 22 of Set 8 | jacareacanga
# Processing Record 23 of Set 8 | balgazyn
# Processing Record 24 of Set 8 | narsaq
# Processing Record 25 of Set 8 | santa fe
# Processing Record 26 of Set 8 | adolfo lopez mateos
# Processing Record 27 of Set 8 | vila franca do campo
# Processing Record 28 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 29 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 30 of Set 8 | haines junction
# Processing Record 31 of Set 8 | zhigansk
# Processing Record 32 of Set 8 | ritterhude
# Processing Record 33 of Set 8 | caimito
# Processing Record 34 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 35 of Set 8 | ontario
# Processing Record 36 of Set 8 | cairns
# Processing Record 37 of Set 8 | saldanha
# Processing Record 38 of Set 8 | rabo de peixe
# Processing Record 39 of Set 8 | ambilobe
# Processing Record 40 of Set 8 | khani
# Processing Record 41 of Set 8 | tautira
# Processing Record 42 of Set 8 | langsa
# Processing Record 43 of Set 8 | isoka
# Processing Record 44 of Set 8 | tateyama
# Processing Record 45 of Set 8 | pilar
# Processing Record 46 of Set 8 | lastoursville
# Processing Record 47 of Set 8 | vostok
# Processing Record 48 of Set 8 | vila
# Processing Record 49 of Set 8 | asosa
# Processing Record 50 of Set 8 | parsabad
# Processing Record 1 of Set 9 | kahului
# Processing Record 2 of Set 9 | oxapampa
# Processing Record 3 of Set 9 | mackay
# Processing Record 4 of Set 9 | husavik
# Processing Record 5 of Set 9 | la libertad
# Processing Record 6 of Set 9 | ouadda
# Processing Record 7 of Set 9 | kuusamo
# Processing Record 8 of Set 9 | impfondo
# Processing Record 9 of Set 9 | lasa
# Processing Record 10 of Set 9 | nago
# Processing Record 11 of Set 9 | juneau
# Processing Record 12 of Set 9 | souillac
# Processing Record 13 of Set 9 | port-cartier
# Processing Record 14 of Set 9 | kisangani
# Processing Record 15 of Set 9 | tessalit
# Processing Record 16 of Set 9 | pemangkat
# Processing Record 17 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 9 | ahuimanu
# Processing Record 19 of Set 9 | newport
# Processing Record 20 of Set 9 | calama
# Processing Record 21 of Set 9 | sijunjung
# Processing Record 22 of Set 9 | lodja
# Processing Record 23 of Set 9 | porto walter
# Processing Record 24 of Set 9 | portland
# Processing Record 25 of Set 9 | tiksi
# Processing Record 26 of Set 9 | mayo
# Processing Record 27 of Set 9 | rancho palos verdes
# Processing Record 28 of Set 9 | el paso
# Processing Record 29 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 9 | antofagasta
# Processing Record 31 of Set 9 | povolzhskiy
# Processing Record 32 of Set 9 | mirnyy
# Processing Record 33 of Set 9 | madhupur
# Processing Record 34 of Set 9 | erenhot
# Processing Record 35 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 36 of Set 9 | odesskoye
# Processing Record 37 of Set 9 | axim
# Processing Record 38 of Set 9 | saint-joseph
# Processing Record 39 of Set 9 | mount isa
# Processing Record 40 of Set 9 | troitskoye
# Processing Record 41 of Set 9 | coruripe
# Processing Record 42 of Set 9 | la ligua
# Processing Record 43 of Set 9 | morant bay
# Processing Record 44 of Set 9 | baculin
# Processing Record 45 of Set 9 | hirara
# Processing Record 46 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 9 | havelock
# Processing Record 48 of Set 9 | saint-pierre
# Processing Record 49 of Set 9 | kirakira
# Processing Record 50 of Set 9 | ngunguru
# Processing Record 1 of Set 10 | dauriya
# Processing Record 2 of Set 10 | komsomolskiy
# Processing Record 3 of Set 10 | lorengau
# Processing Record 4 of Set 10 | karratha
# Processing Record 5 of Set 10 | jalu
# Processing Record 6 of Set 10 | nioki
# Processing Record 7 of Set 10 | provideniya
# Processing Record 8 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 9 of Set 10 | costa rica
# Processing Record 10 of Set 10 | conceicao do araguaia
# Processing Record 11 of Set 10 | kremenchuk
# Processing Record 12 of Set 10 | maralal
# Processing Record 13 of Set 10 | adrar
# Processing Record 14 of Set 10 | sur
# Processing Record 15 of Set 10 | vodstroy
# Processing Record 16 of Set 10 | villa rica
# Processing Record 17 of Set 10 | tuatapere
# Processing Record 18 of Set 10 | constitucion
# Processing Record 19 of Set 10 | bontang
# Processing Record 20 of Set 10 | katsuura
# Processing Record 21 of Set 10 | karaton
# Processing Record 22 of Set 10 | tsumeb
# Processing Record 23 of Set 10 | zhuhai
# Processing Record 24 of Set 10 | ust-kuyga
# Processing Record 25 of Set 10 | sarai mir
# Processing Record 26 of Set 10 | arys
# Processing Record 27 of Set 10 | aleksandrov gay
# Processing Record 28 of Set 10 | freeport
# Processing Record 29 of Set 10 | athabasca
# Processing Record 30 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 10 | okha
# Processing Record 32 of Set 10 | manyana
# Processing Record 33 of Set 10 | la ronge
# Processing Record 34 of Set 10 | smoky lake
# Processing Record 35 of Set 10 | san cristobal
# Processing Record 36 of Set 10 | ivancice
# Processing Record 37 of Set 10 | saveh
# Processing Record 38 of Set 10 | rizal
# Processing Record 39 of Set 10 | saint george
# Processing Record 40 of Set 10 | rincon
# Processing Record 41 of Set 10 | ajaccio
# Processing Record 42 of Set 10 | machico
# Processing Record 43 of Set 10 | ust-ilimsk
# Processing Record 44 of Set 10 | kavaratti
# Processing Record 45 of Set 10 | sebezh
# Processing Record 46 of Set 10 | gunjur
# Processing Record 47 of Set 10 | gayeri
# Processing Record 48 of Set 10 | suixi
# Processing Record 49 of Set 10 | monroe
# Processing Record 50 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 11 | poum
# Processing Record 2 of Set 11 | jacmel
# Processing Record 3 of Set 11 | hastings
# Processing Record 4 of Set 11 | loiza
# Processing Record 5 of Set 11 | verkhoyansk
# Processing Record 6 of Set 11 | gornopravdinsk
# Processing Record 7 of Set 11 | podyuga
# Processing Record 8 of Set 11 | udachnyy
# Processing Record 9 of Set 11 | soyo
# Processing Record 10 of Set 11 | kaitangata
# Processing Record 11 of Set 11 | shingu
# Processing Record 12 of Set 11 | half moon bay
# Processing Record 13 of Set 11 | tazovskiy
# Processing Record 14 of Set 11 | sao filipe
# Processing Record 15 of Set 11 | vaitape
# Processing Record 16 of Set 11 | usinsk
# Processing Record 17 of Set 11 | esperance
# Processing Record 18 of Set 11 | starodub
# Processing Record 19 of Set 11 | meulaboh
# Processing Record 20 of Set 11 | sidi bin nur
# Processing Record 21 of Set 11 | kokuy
# Processing Record 22 of Set 11 | tura
# Processing Record 23 of Set 11 | bunia
# Processing Record 24 of Set 11 | manado
# Processing Record 25 of Set 11 | qasigiannguit
# Processing Record 26 of Set 11 | gubkin
# Processing Record 27 of Set 11 | chingirlau
# Processing Record 28 of Set 11 | lekoni
# Processing Record 29 of Set 11 | pafos
# Processing Record 30 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 11 | russell
# Processing Record 32 of Set 11 | fatsa
# Processing Record 33 of Set 11 | broome
# Processing Record 34 of Set 11 | port hardy
# Processing Record 35 of Set 11 | leh
# Processing Record 36 of Set 11 | grand gaube
# Processing Record 37 of Set 11 | mukhen
# Processing Record 38 of Set 11 | puyang
# Processing Record 39 of Set 11 | carbonia
# Processing Record 40 of Set 11 | bogande
# Processing Record 41 of Set 11 | bagdarin
# Processing Record 42 of Set 11 | manaquiri
# Processing Record 43 of Set 11 | grand forks
# Processing Record 44 of Set 11 | balkhash
# Processing Record 45 of Set 11 | nome
# Processing Record 46 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 11 | laguna
# Processing Record 48 of Set 11 | mnogovershinnyy
# Processing Record 49 of Set 11 | rossland
# Processing Record 50 of Set 11 | urumqi
# Processing Record 1 of Set 12 | consolacion del sur
# Processing Record 2 of Set 12 | boyolangu
# Processing Record 3 of Set 12 | solnechnyy
# Processing Record 4 of Set 12 | tulle
# Processing Record 5 of Set 12 | ewing
# Processing Record 6 of Set 12 | lugovoy
# Processing Record 7 of Set 12 | yuncheng
# Processing Record 8 of Set 12 | kita
# Processing Record 9 of Set 12 | asfi
# Processing Record 10 of Set 12 | wahiawa
# Processing Record 11 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 12 of Set 12 | altay
# Processing Record 13 of Set 12 | bell ville
# Processing Record 14 of Set 12 | huarmey
# Processing Record 15 of Set 12 | tulun
# Processing Record 16 of Set 12 | panguna
# Processing Record 17 of Set 12 | sisophon
# Processing Record 18 of Set 12 | lavrentiya
# Processing Record 19 of Set 12 | coahuayana
# Processing Record 20 of Set 12 | watertown
# Processing Record 21 of Set 12 | bantou
# Processing Record 22 of Set 12 | mokhsogollokh
# Processing Record 23 of Set 12 | quelimane
# Processing Record 24 of Set 12 | beloha
# Processing Record 25 of Set 12 | bima
# Processing Record 26 of Set 12 | marawi
# Processing Record 27 of Set 12 | cerqueira cesar
# Processing Record 28 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 29 of Set 12 | yaan
# Processing Record 30 of Set 12 | nadvoitsy
# Processing Record 31 of Set 12 | ambulu
# Processing Record 32 of Set 12 | pojuca
# Processing Record 33 of Set 12 | jamsa
# Processing Record 34 of Set 12 | kiunga
# Processing Record 35 of Set 12 | san jose
# Processing Record 36 of Set 12 | buala
# Processing Record 37 of Set 12 | fatehpur
# Processing Record 38 of Set 12 | urucara
# Processing Record 39 of Set 12 | hervey bay
# Processing Record 40 of Set 12 | kamaishi
# Processing Record 41 of Set 12 | longyearbyen
# Processing Record 42 of Set 12 | shasta lake
# Processing Record 43 of Set 12 | morondava
# Processing Record 44 of Set 12 | jutai
# Processing Record 45 of Set 12 | cocobeach
# Processing Record 46 of Set 12 | cabedelo
# Processing Record 47 of Set 12 | muscle shoals
# Processing Record 48 of Set 12 | seminole
# Processing Record 49 of Set 12 | ostrovnoy
# Processing Record 50 of Set 12 | saskatoon
# Processing Record 1 of Set 13 | kuchinarai
# Processing Record 2 of Set 13 | fuerte olimpo
# Processing Record 3 of Set 13 | grindavik
# Processing Record 4 of Set 13 | airai
# Processing Record 5 of Set 13 | antibes
# Processing Record 6 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 13 | sinnamary
# Processing Record 8 of Set 13 | batagay
# Processing Record 9 of Set 13 | yumen
# Processing Record 10 of Set 13 | channel-port aux basques
# Processing Record 11 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 12 of Set 13 | goundam
# Processing Record 13 of Set 13 | bata
# Processing Record 14 of Set 13 | ixtapa
# Processing Record 15 of Set 13 | edremit
# Processing Record 16 of Set 13 | springfield
# Processing Record 17 of Set 13 | jibuti
# Processing Record 18 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 19 of Set 13 | saint-francois
# Processing Record 20 of Set 13 | jurado
# Processing Record 21 of Set 13 | shenjiamen
# Processing Record 22 of Set 13 | manono
# Processing Record 23 of Set 13 | encruzilhada
# Processing Record 24 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 13 | novomykolayivka
# Processing Record 26 of Set 13 | pidhaytsi
# Processing Record 27 of Set 13 | pokosnoye
# Processing Record 28 of Set 13 | san andres
# Processing Record 29 of Set 13 | nguru
# Processing Record 30 of Set 13 | mandan
# Processing Record 31 of Set 13 | vanderhoof
# Processing Record 32 of Set 13 | port said
# Processing Record 33 of Set 13 | potosi
# Processing Record 34 of Set 13 | ocos
# Processing Record 35 of Set 13 | manggar
# Processing Record 36 of Set 13 | pokhara
# Processing Record 37 of Set 13 | taunggyi
# Processing Record 38 of Set 13 | lensk
# Processing Record 39 of Set 13 | desaguadero
# Processing Record 40 of Set 13 | marovoay
# Processing Record 41 of Set 13 | bat khela
# Processing Record 42 of Set 13 | huilong
# Processing Record 43 of Set 13 | west wendover
# Processing Record 44 of Set 13 | jingdezhen
# Processing Record 45 of Set 13 | lexington park
# Processing Record 46 of Set 13 | alta floresta
# Processing Record 47 of Set 13 | polson
# Processing Record 48 of Set 13 | gweru
# Processing Record 49 of Set 13 | kamiiso
# Processing Record 50 of Set 13 | riyadh
# Processing Record 1 of Set 14 | tsiroanomandidy
# Processing Record 2 of Set 14 | amnat charoen
# Processing Record 3 of Set 14 | imeni poliny osipenko
# Processing Record 4 of Set 14 | henties bay
# Processing Record 5 of Set 14 | baglan
# Processing Record 6 of Set 14 | oskaloosa
# Processing Record 7 of Set 14 | pryazha
# Processing Record 8 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 14 | kaberamaido
# Processing Record 10 of Set 14 | veraval
# Processing Record 11 of Set 14 | gimli
# Processing Record 12 of Set 14 | talakan
# Processing Record 13 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 14 of Set 14 | svetlaya
# Processing Record 15 of Set 14 | wladyslawowo
# Processing Record 16 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 17 of Set 14 | vilyuysk
# Processing Record 18 of Set 14 | ranong
# Processing Record 19 of Set 14 | oussouye
# Processing Record 20 of Set 14 | evinayong
# Processing Record 21 of Set 14 | shiraz
# Processing Record 22 of Set 14 | viedma
# Processing Record 23 of Set 14 | goleniow
# Processing Record 24 of Set 14 | waingapu
# Processing Record 25 of Set 14 | pacific grove
# Processing Record 26 of Set 14 | tranas
# Processing Record 27 of Set 14 | east bethel
# Processing Record 28 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 14 | jiazi
# Processing Record 30 of Set 14 | kerema
# Processing Record 31 of Set 14 | nanakuli
# Processing Record 32 of Set 14 | canutama
# Processing Record 33 of Set 14 | paso de patria
# Processing Record 34 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 14 | shumskiy
# Processing Record 36 of Set 14 | eyl
# Processing Record 37 of Set 14 | itarema
# Processing Record 38 of Set 14 | omsk
# Processing Record 39 of Set 14 | vohibinany
# Processing Record 40 of Set 14 | ongandjera
# Processing Record 41 of Set 14 | aljezur
# Processing Record 42 of Set 14 | yeppoon
# Processing Record 43 of Set 14 | gao
# Processing Record 44 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 14 | auch
# Processing Record 46 of Set 14 | mehamn
# Processing Record 47 of Set 14 | rafai
# Processing Record 48 of Set 14 | sao joao da barra
# Processing Record 49 of Set 14 | moskovskiy
# Processing Record 50 of Set 14 | hit
# Processing Record 1 of Set 15 | wonthaggi
# Processing Record 2 of Set 15 | bangassou
# Processing Record 3 of Set 15 | luangwa
# Processing Record 4 of Set 15 | charleston
# Processing Record 5 of Set 15 | acapulco
# Processing Record 6 of Set 15 | gremyachye
# City not found. Skipping...
# Processing Record 7 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 15 | pangnirtung
# Processing Record 9 of Set 15 | kyra
# Processing Record 10 of Set 15 | yelizovo
# Processing Record 11 of Set 15 | thilogne
# City not found. Skipping...
# Processing Record 12 of Set 15 | ewo
# Processing Record 13 of Set 15 | rayong
# Processing Record 14 of Set 15 | camasca
# Processing Record 15 of Set 15 | burley
# Processing Record 16 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 17 of Set 15 | lebanon
# Processing Record 18 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 15 | tingo maria
# Processing Record 20 of Set 15 | zhongxing
# Processing Record 21 of Set 15 | katherine
# Processing Record 22 of Set 15 | punta cardon
# Processing Record 23 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 15 | pemberton
# Processing Record 25 of Set 15 | ugoofaaru
# Processing Record 26 of Set 15 | danshui
# Processing Record 27 of Set 15 | thinadhoo
# Processing Record 28 of Set 15 | puerto escondido
# Processing Record 29 of Set 15 | robe
# Processing Record 30 of Set 15 | krasnoselkup
# Processing Record 31 of Set 15 | kieta
# Processing Record 32 of Set 15 | shubarshi
# Processing Record 33 of Set 15 | sakakah
# Processing Record 34 of Set 15 | araripina
# Processing Record 35 of Set 15 | tangjiazhuang
# Processing Record 36 of Set 15 | kaniama
# Processing Record 37 of Set 15 | goderich
# Processing Record 38 of Set 15 | kibala
# Processing Record 39 of Set 15 | estelle
# Processing Record 40 of Set 15 | redcar
# Processing Record 41 of Set 15 | banda aceh
# Processing Record 42 of Set 15 | hays
# Processing Record 43 of Set 15 | nizhneudinsk
# Processing Record 44 of Set 15 | seryshevo
# Processing Record 45 of Set 15 | antalaha
# Processing Record 46 of Set 15 | ixmiquilpan
# Processing Record 47 of Set 15 | lazaro cardenas
# Processing Record 48 of Set 15 | nuuk
# Processing Record 49 of Set 15 | takoradi
# Processing Record 50 of Set 15 | camacha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Victoria      HK  22.2855  114.1577     87.96        83         100
# 1   Cape Town      ZA -33.9258   18.4232     58.12        87          82
# 2    Vanavara      RU  60.3400  102.2797     54.36        64          91
# 3      Bonthe      SL   7.5264  -12.5050     79.70        80          99
# 4  Chokurdakh      RU  70.6333  147.9167     36.81        59         100
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1        7.05       broken clouds
# 2        1.07     overcast clouds
# 3        7.07     overcast clouds
# 4       17.05     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
